# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df.head()

crash_df=crash_df.drop(columns='abbrev')

# %% [markdown]
# DISTRIBUTION PLOT

# %%
sns.displot(crash_df['not_distracted'],kde=True,color=('red'),bins=10)

# %% [markdown]
# JOINT PLOT

# %%
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='kde')

# %%
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='hex')

# %%
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='hist')

# %%
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')

# %% [markdown]
# KDE PLOT

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# PAIR PLOTS

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')

sns.pairplot(tips_df, hue='sex',palette='Blues')

# %% [markdown]
# RUG PLOT

# %%
sns.rugplot(tipd_df['tip'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 sns.rugplot(tipd_df['tip'])
#
# NameError: name 'tipd_df' is not defined

# %% [markdown]
# STYLING

# %%
sns.set_style('dark')

sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,5))

sns.set_context('paper', font_scale=1.5)


sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')

sns.despine(left=True,bottom=True)

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(8,5))

sns.set_context('poster', font_scale=1.5)


sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')
# Out:
# c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1766: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   f.tight_layout()

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(8,5))

sns.set_context('talk', font_scale=1.5)


sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')

# %% [markdown]
# BAR PLOTS

# %%
sns.barplot(x='sex',y='total_bill',data=tipd_df,estimator=np.var)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# COUNT PLOT

# %%
sns.countplot(x='sex',data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# BOX PLOT

# %%
sns.boxplot(x='day',y='total_bill',data=tips_df,hue='sex')

plt.legend(loc=0)

# %% [markdown]
# VIOLIN PLOT

# %%
sns.violinplot(x='day',y='total_bill',data=tips_df,hue='sex',split=True)

plt.legend(loc=0)

# %% [markdown]
# STRIP PLOT

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True,hue='sex',dodge=True)

plt.legend(loc=0)

# %% [markdown]
# SWARM PLOT

# %%
sns.violinplot(x='day',y='total_bill',data=tips_df)

sns.swarmplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# PALETTES

# %%
plt.figure(figsize=(8,5))

sns.set_style('dark')

sns.set_context('talk')

sns.stripplot(x='day',y='total_bill',data=tips_df,hue='sex',palette='magma')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,6))

sns.set_style('white')

sns.set_context('talk')

sns.stripplot(x='day',y='total_bill',data=tips_df,hue='sex',palette='afmhot')

plt.legend(loc=0)

# %% [markdown]
# MATRIX PLOTS

# %% [markdown]
# HEATMAPS

# %%
plt.figure(figsize=(8,5))

sns.set_context('paper',font_scale=1.5)

#Needed to remove the last column 'Abev" as it did not have any numerical values which it can correlate
crash_mx=crash_df.corr()

sns.heatmap(crash_mx,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights')

flights = flights.pivot_table(index='month',columns='year',values='passengers')

flights

sns.heatmap(flights,cmap='twilight',linecolor='white',linewidths=1)
# Out:
# C:\Users\Krish\AppData\Local\Temp\ipykernel_12460\29794706.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights = flights.pivot_table(index='month',columns='year',values='passengers')
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# CLUSTER MAPS

# %%
iris = sns.load_dataset('iris')

species=iris.pop('species')
sns.clustermap(iris)

# %%
sns.clustermap(flights,cmap='Blues',standard_scale=1)

# %% [markdown]
# PAIR GRIDS

# %%
iris=sns.load_dataset('iris')

iris_g = sns.PairGrid(iris,hue="species")

iris_g.map(plt.scatter)

iris_g.map_diag(plt.hist)

# %%
iris=sns.load_dataset('iris')

iris_g = sns.PairGrid(iris,hue="species")

iris_g.map_diag(plt.hist)

iris_g.map_offdiag(plt.scatter)

# %%
iris=sns.load_dataset('iris')

iris_g = sns.PairGrid(iris,hue="species")

iris_g.map_upper(plt.scatter)

iris_g.map_lower(sns.kdeplot)

iris_g.map_diag(plt.hist)

# %%
iris_g=sns.PairGrid(iris,hue="species",x_vars=['sepal_length','sepal_width'],y_vars=['petal_length','petal_width'])

iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# FACET GRID

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')

tips_fg.map(plt.scatter, 'total_bill','tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker',height=4,aspect=1.3, col_order=['Dinner', 'Lunch'], palette='Set1')

tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
kws = dict(s=50, linewidth=.5, edgecolor='w')

tips_fg = sns.FacetGrid(tips_df, col='sex', hue='smoker', height=4, aspect=1.3, hue_order=['Yes', 'No'], hue_kws=dict(marker=['^', 'v']))

tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)

# %%
att_df = sns.load_dataset('attention')

att_fg = sns.FacetGrid(att_df, col='subject', col_wrap=5, height=1.5)

att_fg.map(plt.plot, 'solutions', 'score', marker='^')

# %% [markdown]
# REGRESSION PLOTS

# %%
plt.Figure(figsize=(8,6))

sns.set_context('paper', font_scale=1.4)

sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o','^'], scatter_kws={'s':100, 'linewidth':0.5, 'edgecolor':'w'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 5
#       1 plt.Figure(figsize=(8,6))
#       3 sns.set_context('paper', font_scale=1.4)
# ----> 5 sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o','^'], scatter_kws={'s':100, 'linewidth':0.5, 'edgecolor':'w'})
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\regression.py:651, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
#     644     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
#     645     scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
#    (...)
#     649     scatter_kws=scatter_kws, line_kws=line_kws,
#     650 )
# --> 651 facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     652 facets.set_axis_labels(x, y)
#     654 # Add a legend
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:825, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     822     kwargs["data"] = data_ijk
#     824     # Draw the plot
# --> 825     self._facet_plot(func, ax, args, kwargs)
#     827 # For axis labels, prefer to use positional args for backcompat
#     828 # but also extract the x/y kwargs and use if no corresponding arg
#     829 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\regression.py:381, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     379 # Draw the constituent plots
#     380 if self.scatter:
# --> 381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
#     384     self.lineplot(ax, line_kws)
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\regression.py:411, in _RegressionPlotter.scatterplot(self, ax, kws)
#     408         kws.setdefault("alpha", .8)
#     410     x, y = self.scatter_data
# --> 411     ax.scatter(x, y, **kws)
#     412 else:
#     413     # TODO abstraction
#     414     ci_kws = {"color": kws["color"]}
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
#    1493                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:4775, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4772 if linewidths is not None:
#    4773     kwargs.update({'linewidths': linewidths})
# -> 4775 kwargs = cbook.normalize_kwargs(kwargs, mcoll.Collection)
#    4776 # re direct linewidth and edgecolor so it can be
#    4777 # further processed by the rest of the function
#    4778 linewidths = kwargs.pop('linewidth', None)
#
# File c:\Users\Krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\cbook.py:1843, in normalize_kwargs(kw, alias_mapping)
#    1841 canonical = to_canonical.get(k, k)
#    1842 if canonical in canonical_to_seen:
# -> 1843     raise TypeError(f"Got both {canonical_to_seen[canonical]!r} and "
#    1844                     f"{k!r}, which are aliases of one another")
#    1845 canonical_to_seen[canonical] = k
#    1846 ret[canonical] = v
#
# TypeError: Got both 'linewidth' and 'linewidths', which are aliases of one another
